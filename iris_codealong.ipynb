# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
iris = pd.read_csv('iris.csv')

# %%
#explore shape and columns
print(iris.shape)
print(iris.columns)
# Out:
# (150, 6)
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#see distribution of species
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#scatter plot
iris.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
plt.show()

# %%
#spruce up with seaborn
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue='Species', size=4) \
    .map(plt.scatter, 'SepalLengthCm', 'SepalWidthCm') \
    .add_legend()
plt.show()
# Out:
# /Users/conorsmith/Desktop/mle_code_along/env/lib/python3.10/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
